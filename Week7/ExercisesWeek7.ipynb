# %% [markdown]
# <a href="https://colab.research.google.com/github/geffenmoser/di_tta114_geffen_moser/blob/main/ExercisesWeek7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercise 1:
#  Data analysis is the career field that uses software to compute large sums of data for the sake of deriving, presenting, and explaining the information provided by statistical analysis of the given data sets. In a modern context, most industries depend on using patterns and information based on large data sets to make informed decisions, whether its a hospital keeping track of efficiency, a business observing trends from their website's traffic to make decisions, or a human resources department interpreting the results of an internal survey, the availability of large data processing software and the blooming career of data analytics has allowed for empirically informed decision-making in every industry.

# %%
# !pip install kaggle

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

# Then move kaggle.json into the folder where the API expects to find it.
# !mkdir -p ~/.kaggle/ && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-c6fe7659-294b-46f1-a74f-cee2dafb9920" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c6fe7659-294b-46f1-a74f-cee2dafb9920">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets download -d samuelcortinhas/credit-card-approval-clean-data
# Out:
# Dataset URL: https://www.kaggle.com/datasets/samuelcortinhas/credit-card-approval-clean-data
# License(s): CC0-1.0
# credit-card-approval-clean-data.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip credit-card-approval-clean-data.zip
# Out:
# Archive:  credit-card-approval-clean-data.zip
#   inflating: clean_dataset.csv
#   inflating: crx.csv

# %%
import pandas as pd
cc_data = pd.read_csv('clean_dataset.csv')
print(cc_data.head())
# Out:
#    Gender    Age   Debt  Married  BankCustomer     Industry Ethnicity  \
# 0       1  30.83  0.000        1             1  Industrials     White
# 1       0  58.67  4.460        1             1    Materials     Black
# 2       0  24.50  0.500        1             1    Materials     Black
# 3       1  27.83  1.540        1             1  Industrials     White
# 4       1  20.17  5.625        1             1  Industrials     White
#
#    YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0           1.25             1         1            1               0
# 1           3.04             1         1            6               0
# 2           1.50             1         0            0               0
# 3           3.75             1         1            5               1
# 4           1.71             1         0            0               0
#
#         Citizen  ZipCode  Income  Approved
# 0       ByBirth      202       0         1
# ...

# %% [markdown]
# Exercise3:
# The Quantitative columns are: age, debt, YearsEmployed, CreditScore, and income. This means they are based in a fixed numeric ratio with a starting point rather than categorical data.
# The Qualitative columns are: Gender, Married, BankCustomer, Industry, Ethnicity, PriorDefault, Employed, DriversLicense, Citizen, Zipcode, Approved. This means that the information is not numeric or ordered in relation.

# %%
import matplotlib.pyplot as plt
Age = cc_data['Age']
print(Age.describe())
plt.plot(cc_data['Age'], cc_data['Employed'])
plt.show()
# Out:
# count    690.000000
# mean      31.514116
# std       11.860245
# min       13.750000
# 25%       22.670000
# 50%       28.460000
# 75%       37.707500
# max       80.250000
# Name: Age, dtype: float64

# %%
# !kaggle datasets download -d thedevastator/how-much-sleep-do-americans-really-get
# Out:
# Dataset URL: https://www.kaggle.com/datasets/thedevastator/how-much-sleep-do-americans-really-get
# License(s): copyright-authors
# ...
#   0% 0.00/7.62k [00:00<?, ?B/s]
# 100% 7.62k/7.62k [00:00<00:00, 17.2MB/s]

# %%
# !unzip how-much-sleep-do-americans-really-get.zip
# Out:
# Archive:  how-much-sleep-do-americans-really-get.zip
#   inflating: Time Americans Spend Sleeping.csv

# %%
sleep_data = pd.read_csv('Time Americans Spend Sleeping.csv')
print(sleep_data.head())
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both

# %% [markdown]
# Exercise 6: I think it would be interesting to see how average sleep time across all groups has changed over the 20 years that this set has data for.
